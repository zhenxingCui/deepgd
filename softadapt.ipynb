    877.29,
    879.4 ,
    875.57,
    873.39,
    873.45,
    875.4 ,
    877.95,
    874.94,
    870.32,
    872.83,
    877.44,
    879.61,
    876.29,
    874.76,
    869.59,
    873.06,
    870.86,
    872.79,
    872.87,
    874.86,
    873.84,
    873.03,
    871.03,
    871.09,
    871.03,
    873.07,
    871.4 ,
    869.15,
    872.65,
    869.24,
    873.37,
    868.82,
    873.59,
    868.23,
    873.66,
    868.05,
    867.63,
    872.54,
    869.76,
    867.97,
    870.45,
    866.06,
    870.78,
    871.22,
    867.46,
    866.57,
    870.42,
    869.42,
    871.86,
    868.23,
    868.27
])

# %%
np.array(gamma) / np.sum(gamma)
# Out:
# array([[0.9, 0.1]])

# %%
losses = np.zeros([2, 2])
eps = 1e-5
gamma = [[0.9, 0.1]]
beta = -1

# %%
losses
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
roc = np.diff(losses, axis=0) / (losses[:-1] + eps)

# %%
normalized_roc = roc / (np.abs(roc).sum(axis=1)[:, None] + eps)

# %%
weight = np.array(gamma)[None, :] * np.exp(beta * normalized_roc) / (losses[1:] + eps)

# %%
weight / (weight.sum(axis=1)[:, None] + eps)
# Out:
# array([[[1., 1.]]])

# %%
losses = np.stack([stress, angle], axis=1)
smoothed = np.zeros([2,2])#SoftAdaptController._exp_smooth(losses, tau=0.95)
weights = SoftAdaptController._soft_adapt(smoothed, gamma=[1, 1], beta=1)

# %%
weights
# Out:
# array([[0.5, 0.5]])

# %%
idx = 170
print((np.diff(smoothed, axis=0) / losses[:-1])[idx])
print(weights[idx])
# Out:
# [-0.00035851 -0.00056347]
# [0.445603 0.554397]

# %%
# Out:
# array([0.46248751, 0.53751249])

# %%
roc = np.diff(smoothed, axis=0)
normalized_roc = roc / (np.abs(roc).sum(axis=1)[:, None] + 1e-5)
exp_beta_roc = np.exp(1 * normalized_roc)
loss_weighted = smoothed[1:] * exp_beta_roc
loss_weighted / loss_weighted.sum(axis=1)[:, None]
# Out:
# array([[0.40580868, 0.59419132],
#        [0.41905081, 0.58094919],
#        [0.4240919 , 0.5759081 ],
#        [0.41860073, 0.58139927],
#        [0.4231122 , 0.5768878 ],
#        [0.42162332, 0.57837668],
#        [0.41826544, 0.58173456],
#        [0.41813996, 0.58186004],
#        [0.42025833, 0.57974167],
#        [0.4211594 , 0.5788406 ],
#        [0.41909847, 0.58090153],
#        [0.41790979, 0.58209021],
#        [0.41945182, 0.58054818],
#        [0.41249604, 0.58750396],
#        [0.41314162, 0.58685838],
#        [0.40789372, 0.59210628],
#        [0.40657077, 0.59342923],
#        [0.41115862, 0.58884138],
#        [0.40778605, 0.59221395],
#        [0.41194988, 0.58805012],
#        [0.40922965, 0.59077035],
#        [0.40802218, 0.59197782],
#        [0.41264797, 0.58735203],
#        [0.41441045, 0.58558955],
#        [0.41227565, 0.58772435],
#        [0.41253709, 0.58746291],
#        [0.40282537, 0.59717463],
#        [0.40902662, 0.59097338],
# ...

# %%
plt.figure()
plt.plot(stress-np.min(stress))
plt.plot(exp_smooth(stress, 0.95)-np.min(stress))
plt.yscale('log')

# %%
a = np.array([-100, -101, -102, -103])
b = np.array([0, -1, -2, -3])

np.exp(b) / np.exp(b).sum()
# Out:
# array([0.64391426, 0.23688282, 0.08714432, 0.0320586 ])

# %%
f'{1:03}'
# Out:
# '001'
